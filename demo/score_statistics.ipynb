# %% [markdown]
# ### 1. Import packages

# %%
from build_dataset import Corpus
from statistics import Statistic

# %% [markdown]
# ### 2. Read the corpus

# %%
train, dev, test = Corpus().read_corpus()

# %% [markdown]
# ### 3. Get some statistics

# %%
stat = Statistic(train)

# plot the top ten scores of the training set
stat.plot_score(10)

# %%
stat = Statistic(dev)

# plot the top ten scores of the development set
stat.plot_score(10)

# %%
stat = Statistic(test)

# plot the top ten scores of the testing set
stat.plot_score(10)
